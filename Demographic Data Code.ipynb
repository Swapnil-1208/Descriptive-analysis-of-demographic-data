# %% [markdown]
# # GETTING SYSTEM READY AND LOADING THE DATA

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.5

# %%
#Loading the required Packages

import pandas as pd     #for data analysis
import matplotlib.pyplot as plt     #for plotting graphs
# %matplotlib inline
import seaborn as sns     #for plotting graphs(more detailed and interactive graphs)

# %%
df=pd.read_csv('census_2020_2000.csv',encoding='Latin-1')     #reading the .csv file using Pandas library

# %%
df
# Out:
#     Country.Area.Name FIPS GENC           Subregion  Region  Year  \
# 0         Afghanistan   AF   AF  South-Central Asia    Asia  2000
# 1         Afghanistan   AF   AF  South-Central Asia    Asia  2020
# 2             Albania   AL   AL     Southern Europe  Europe  2000
# 3             Albania   AL   AL     Southern Europe  Europe  2020
# 4             Algeria   AG   DZ     Northern Africa  Africa  2000
# ..                ...  ...  ...                 ...     ...   ...
# 451             Yemen   YM   YE        Western Asia    Asia  2020
# 452            Zambia   ZA   ZM      Eastern Africa  Africa  2000
# 453            Zambia   ZA   ZM      Eastern Africa  Africa  2020
# 454          Zimbabwe   ZI   ZW      Eastern Africa  Africa  2000
# 455          Zimbabwe   ZI   ZW      Eastern Africa  Africa  2020
#
#      Total.Fertility.Rate  Life.Expectancy.at.Birth..Both.Sexes  \
# 0                  8.0000                                 45.49
# ...

# %% [markdown]
# # UNDERSTANDING THE DATA

# %%
df.head()     #fetching the first five rows of our data
# Out:
#   Country.Area.Name FIPS GENC           Subregion  Region  Year  \
# 0       Afghanistan   AF   AF  South-Central Asia    Asia  2000
# 1       Afghanistan   AF   AF  South-Central Asia    Asia  2020
# 2           Albania   AL   AL     Southern Europe  Europe  2000
# 3           Albania   AL   AL     Southern Europe  Europe  2020
# 4           Algeria   AG   DZ     Northern Africa  Africa  2000
#
#    Total.Fertility.Rate  Life.Expectancy.at.Birth..Both.Sexes  \
# 0                8.0000                                 45.49
# 1                4.8200                                 52.84
# 2                2.1716                                 74.70
# 3                1.5288                                 78.99
# 4                2.3654                                 71.84
#
#    Life.Expectancy.at.Birth..Males  Life.Expectancy.at.Birth..Females
# 0                            44.55                              46.48
# ...

# %%
df.columns    #checking the features present in the dataset
# Out:
# Index(['Country.Area.Name', 'FIPS', 'GENC', 'Subregion', 'Region', 'Year',
#        'Total.Fertility.Rate', 'Life.Expectancy.at.Birth..Both.Sexes',
#        'Life.Expectancy.at.Birth..Males', 'Life.Expectancy.at.Birth..Females'],
#       dtype='object')

# %%
df.dtypes     #checking datatypes of the features
# Out:
# Country.Area.Name                        object
# FIPS                                     object
# GENC                                     object
# Subregion                                object
# Region                                   object
# Year                                      int64
# Total.Fertility.Rate                    float64
# Life.Expectancy.at.Birth..Both.Sexes    float64
# Life.Expectancy.at.Birth..Males         float64
# Life.Expectancy.at.Birth..Females       float64
# dtype: object

# %%
df.shape     #checking the shape of the dataset, containing 456 records and 10 features
# Out:
# (456, 10)

# %%
df.describe() #to get descriptive analysis of the dataframe
# Out:
#               Year  Total.Fertility.Rate  \
# count   456.000000            449.000000
# mean   2010.000000              2.781093
# std      10.010983              1.478454
# min    2000.000000              0.892400
# 25%    2000.000000              1.710000
# 50%    2010.000000              2.191000
# 75%    2020.000000              3.603500
# max    2020.000000              8.090000
#
#        Life.Expectancy.at.Birth..Both.Sexes  Life.Expectancy.at.Birth..Males  \
# count                            449.000000                       449.000000
# mean                              71.135635                        68.723296
# std                                8.983394                         8.658055
# min                               39.840000                        37.470000
# 25%                               66.740000                        64.560000
# 50%                               73.430000                        70.860000
# ...

# %%
df.isna().sum()     # provides the summation of NA values in our dataset featurewise
# Out:
# Country.Area.Name                       0
# FIPS                                    0
# GENC                                    2
# Subregion                               0
# Region                                  0
# Year                                    0
# Total.Fertility.Rate                    7
# Life.Expectancy.at.Birth..Both.Sexes    7
# Life.Expectancy.at.Birth..Males         7
# Life.Expectancy.at.Birth..Females       7
# dtype: int64

# %% [markdown]
# Comment: There are 7 NA values in 4 features which can be ignored for this case study.
#          Please note: The 2 missing values in the GENC feature is misleading as 'NA' is the encoding present in the feature

# %%
df2020=df[df['Year']==2020]  #Fetching only records where Year=2020 for the first three tasks
df2020.drop(['Year'],axis=1,inplace=True)  #dropping the year columns for the first three task
# Out:
# C:\Users\swapnil\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df2020
# Out:
#     Country.Area.Name FIPS GENC           Subregion   Region  \
# 1         Afghanistan   AF   AF  South-Central Asia     Asia
# 3             Albania   AL   AL     Southern Europe   Europe
# 5             Algeria   AG   DZ     Northern Africa   Africa
# 7      American Samoa   AQ   AS           Polynesia  Oceania
# 9             Andorra   AN   AD     Southern Europe   Europe
# ..                ...  ...  ...                 ...      ...
# 447         West Bank   WE   XW        Western Asia     Asia
# 449    Western Sahara   WI   EH     Northern Africa   Africa
# 451             Yemen   YM   YE        Western Asia     Asia
# 453            Zambia   ZA   ZM      Eastern Africa   Africa
# 455          Zimbabwe   ZI   ZW      Eastern Africa   Africa
#
#      Total.Fertility.Rate  Life.Expectancy.at.Birth..Both.Sexes  \
# 1                  4.8200                                 52.84
# 3                  1.5288                                 78.99
# ...

# %%
df2020.describe() ##to get descriptive analysis of the dataframe
# Out:
#        Total.Fertility.Rate  Life.Expectancy.at.Birth..Both.Sexes  \
# count            228.000000                            228.000000
# mean               2.460568                             74.036930
# std                1.154066                              7.030818
# min                1.060300                             52.840000
# 25%                1.708225                             69.592500
# 50%                2.005950                             75.535000
# 75%                2.872500                             79.217500
# max                7.000000                             89.270000
#
#        Life.Expectancy.at.Birth..Males  Life.Expectancy.at.Birth..Females
# count                       228.000000                         228.000000
# mean                         71.529254                          76.666272
# std                           6.841280                           7.344046
# min                          51.350000                          54.410000
# ...

# %% [markdown]
# # TASK-1

# %% [markdown]
# # FREQUENCY DISTRIBUTION OF THE VARIABLES

# %% [markdown]
# FOR INDEPENDENT NUMERICAL VARIABLE : Using Matplotlib and Seaborn Library(for better and detailed graph)

# %%
fig, axes = plt.subplots(2, 2, figsize=(8, 8))

fig.suptitle('Frequency Distribution of Numerical Variables')

sns.histplot(df2020['Total.Fertility.Rate'],stat='density', ax=axes[0, 0])
sns.histplot(df2020['Life.Expectancy.at.Birth..Females'],stat='density', ax=axes[0, 1])
sns.histplot(df2020['Life.Expectancy.at.Birth..Males'],stat='density', ax=axes[1, 0])
sns.histplot(df2020['Life.Expectancy.at.Birth..Both.Sexes'],stat='density', ax=axes[1, 1])
# Out:
# <AxesSubplot:xlabel='Life.Expectancy.at.Birth..Both.Sexes', ylabel='Density'>

# %% [raw]
# # DIFFERENCES BETWEEN THE SEXES

# %%
a=plt.scatter(df2020['Life.Expectancy.at.Birth..Both.Sexes'], df2020['Life.Expectancy.at.Birth..Females'], color='r')
b=plt.scatter(df2020['Life.Expectancy.at.Birth..Both.Sexes'], df2020['Life.Expectancy.at.Birth..Males'], color='b')
plt.xlabel('Life Expectancy Range')
plt.ylabel('Life Expectancy')
plt.title('Differences between the sexes')
plt.legend((a,b),('Females','Males'))
plt.show()

# %% [markdown]
# # TASK-2

# %% [markdown]
# # BIVARIATE CORRELATIONS BETWEEN THE VARIABLES

# %%
corr=df2020.corr()
corr
# Out:
#                                       Total.Fertility.Rate  \
# Total.Fertility.Rate                              1.000000
# Life.Expectancy.at.Birth..Both.Sexes             -0.802146
# Life.Expectancy.at.Birth..Males                  -0.774607
# Life.Expectancy.at.Birth..Females                -0.818479
#
#                                       Life.Expectancy.at.Birth..Both.Sexes  \
# Total.Fertility.Rate                                             -0.802146
# Life.Expectancy.at.Birth..Both.Sexes                              1.000000
# Life.Expectancy.at.Birth..Males                                   0.992988
# Life.Expectancy.at.Birth..Females                                 0.993381
#
#                                       Life.Expectancy.at.Birth..Males  \
# Total.Fertility.Rate                                        -0.774607
# Life.Expectancy.at.Birth..Both.Sexes                         0.992988
# Life.Expectancy.at.Birth..Males                              1.000000
# ...

# %%
sns.set(rc={'figure.figsize':(8,8)})
sns.heatmap(corr,vmin=-1,vmax=1,annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df2020, size=2.5);
plt.show()
# Out:
# C:\Users\swapnil\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # TASK-3

# %% [markdown]
# # Comparison of variability within and among sub-region

# %%
sns.set(rc={'figure.figsize':(8,8)})

# %%
my_pal = sns.color_palette("bright")

# %%
ax = sns.boxplot(data=(df2020.sort_values(["Region"])),x='Total.Fertility.Rate', y='Subregion', hue='Region', palette=my_pal)
ax.set(xlabel='Total Fertility Rate', ylabel='Sub Regions')
# Out:
# [Text(0.5, 0, 'Total Fertility Rate'), Text(0, 0.5, 'Sub Regions')]

# %%
ax = sns.boxplot(data=(df2020.sort_values(["Region"])),x='Life.Expectancy.at.Birth..Both.Sexes', y='Subregion', hue='Region', palette=my_pal)
ax.set(xlabel='Life Expectancy at Birth : Both Sexes', ylabel='Sub Regions')
# Out:
# [Text(0.5, 0, 'Life Expectancy at Birth : Both Sexes'),
#  Text(0, 0.5, 'Sub Regions')]

# %%
ax = sns.boxplot(data=(df2020.sort_values(["Region"])),x='Life.Expectancy.at.Birth..Males', y='Subregion', hue='Region', palette=my_pal)
ax.set(xlabel='Life Expectancy at Birth : Males', ylabel='Sub Regions')
# Out:
# [Text(0.5, 0, 'Life Expectancy at Birth : Males'), Text(0, 0.5, 'Sub Regions')]

# %%
ax = sns.boxplot(data=(df2020.sort_values(["Region"])),x='Life.Expectancy.at.Birth..Females', y='Subregion', hue='Region', palette=my_pal)
ax.set(xlabel='Life Expectancy at Birth : Females', ylabel='Sub Regions')
# Out:
# [Text(0.5, 0, 'Life Expectancy at Birth : Females'),
#  Text(0, 0.5, 'Sub Regions')]

# %% [markdown]
# # TASK-4

# %% [markdown]
# # YEAR COMPARISON

# %%
year_comparison=df.pivot_table(aggfunc='mean', values=['Total.Fertility.Rate','Life.Expectancy.at.Birth..Both.Sexes','Life.Expectancy.at.Birth..Females','Life.Expectancy.at.Birth..Males'],dropna=True,index=['Year'])
year_comparison
# Out:
#       Life.Expectancy.at.Birth..Both.Sexes  Life.Expectancy.at.Birth..Females  \
# Year
# 2000                             68.142443                          70.585882
# 2020                             74.036930                          76.666272
#
#       Life.Expectancy.at.Birth..Males  Total.Fertility.Rate
# Year
# 2000                        65.828462              3.111771
# 2020                        71.529254              2.460568

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

fig.suptitle('Change in variables from 2000 to 2020')

sns.boxplot(ax=axes[0, 0], data=df, x='Region', y='Life.Expectancy.at.Birth..Females',hue='Year')
sns.boxplot(ax=axes[0, 1], data=df, x='Region', y='Life.Expectancy.at.Birth..Males',hue='Year')
sns.boxplot(ax=axes[1, 0], data=df, x='Region', y='Life.Expectancy.at.Birth..Both.Sexes',hue='Year')
sns.boxplot(ax=axes[1, 1], data=df, x='Region', y='Total.Fertility.Rate',hue='Year')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Total.Fertility.Rate'>
